# %%
# Import libraries
using Turing
using LinearAlgebra
using Distributions
using MultivariateStats
import MultivariateStats: reconstruct
using GaussianProcesses
using StatsBase
using Statistics
using Suppressor
using JLD2
using CSV
using DataFrames, DataFramesMeta
using SplitApplyCombine
using KernelFunctions
using MCMCChains
using PyCall
using PyPlot
using Printf
import PyCall.pyfunction


# Access the matplotlib module
matplotlib = pyimport("matplotlib")
seaborn = pyimport("seaborn")
os = pyimport("os")
pyimport("scienceplots")
np = pyimport("numpy")

plt.style.use(["default","science","no-latex"])
using StatsPlots

seaborn.color_palette("colorblind")

PyCall.pygui(:tk)


FONTSIZE=20.5;

# %%
# Load the standard deviations of the parametric uncertainties over each calibration year
df_std_of_widths = CSV.read("../Data/Parameter_Learning_Tables/param_90_CI_stds_log_gamma0_true.csv", DataFrame)
# Out:
# 19×7 DataFrame
#  Row │ Latest_calibration_year  vmThresh  fricExp     mu_scale    stiff_scale  ⋯
#      │ Float64                  Float64   Float64     Float64     Float64      ⋯
# ─────┼──────────────────────────────────────────────────────────────────────────
#    1 │                  2030.0   1113.99  0.00607815  0.00512485   0.00809918  ⋯
#    2 │                  2045.0   2575.13  0.0177505   0.0318938    0.0292106
#    3 │                  2060.0   2706.31  0.0189843   0.0337416    0.0307668
#    4 │                  2075.0   2925.87  0.0225768   0.0427589    0.0333024
#    5 │                  2090.0   2942.23  0.0233148   0.043653     0.035379    ⋯
#    6 │                  2105.0   2998.73  0.0257989   0.0507735    0.0347254
#    7 │                  2120.0   3273.62  0.0290193   0.053902     0.0393983
#    8 │                  2135.0   3246.9   0.0311529   0.0545192    0.0393994
#    9 │                  2150.0   3479.55  0.0299549   0.0572126    0.0418237   ⋯
#   10 │                  2165.0   3438.83  0.0319858   0.059551     0.0443595
#   11 │                  2180.0   3424.01  0.0332839   0.0622417    0.0414466
#   12 │                  2195.0   3222.03  0.034638    0.049017     0.0359621
#   13 │                  2210.0   3758.49  0.0296432   0.0410191    0.0402798   ⋯
#   14 │                  2225.0   3628.53  0.014989    0.0432835    0.0375209
#   15 │                  2240.0   3631.93  0.0130294   0.0432801    0.0392798
#   16 │                  2255.0   3675.08  0.0099156   0.0407989    0.0369802
#   17 │                  2270.0   3634.1   0.00815542  0.0396276    0.0363849   ⋯
#   18 │                  2285.0   3407.28  0.00728519  0.039055     0.0381583
#   19 │                  2300.0   3212.92  0.0083725   0.0420171    0.0365887
#                                                                2 columns omitted

# %%
#Plot the standard deviations of the parametric uncertainties over each calibration year
colors = Dict(
    1 => "#1f77b4",  # muted blue
    2 => "#ff7f0e",  # orange
    3 => "#2ca02c",  # green
    4 => "#d62728",  # red
    5 => "#9467bd",  # purple
    6 => "#8c564b"   # brown
)
title_dict = Dict(1=>L"\sigma_{max}", 2=>L"q", 3=>L"C_{\mu}", 4=>L"C_{\phi}", 5=>L"\log(\gamma_0)", 6=>L"\overline{m}")
#Plot each parameter's 
fig, ax = PyPlot.subplots(nrows=3, ncols=2, figsize=(18, 11), dpi=300)

for i in 1:6
    
    ax[i].plot(collect(df_std_of_widths.Latest_calibration_year),(collect(df_std_of_widths[:,i+1])), color=colors[i],lw=3 )
    ax[i].set_xlabel(title_dict[i], fontsize = 20)
end
# Out:
# Figure(PyObject <Figure size 5400x3300 with 6 Axes>)

# %%
# Load the standard deviations of the SLR projection uncertainties over each calibration year
df_std_of_widths_slr = CSV.read("../Data/SLR_Learning_Tables/SLR_90_CI_std.csv", DataFrame)
# Out:
# 19×4 DataFrame
#  Row │ Latest year of calibration  2100            2200           2300
#      │ Int64                       Float64?        Float64?       Float64
# ─────┼─────────────────────────────────────────────────────────────────────
#    1 │                       2030        0.428173        7.55148   3.37326
#    2 │                       2045        0.281691       13.7236   10.5032
#    3 │                       2060        0.536669       12.0426   11.053
#    4 │                       2075        0.966906        5.98394  13.738
#    5 │                       2090        1.03229         6.09384  13.8805
#    6 │                       2105  missing               5.36544  14.61
#    7 │                       2120  missing               4.2749   16.135
#    8 │                       2135  missing               3.42037  17.832
#    9 │                       2150  missing               3.13943  16.5074
#   10 │                       2165  missing               3.23594  17.2143
#   11 │                       2180  missing               2.54347  13.6909
#   12 │                       2195  missing               2.25145  12.9465
#   13 │                       2210  missing         missing        11.9086
#   14 │                       2225  missing         missing         5.19055
#   15 │                       2240  missing         missing         3.58407
#   16 │                       2255  missing         missing         3.10861
#   17 │                       2270  missing         missing         2.94408
#   18 │                       2285  missing         missing         2.64747
#   19 │                       2300  missing         missing         2.59225

# %%
# Plot the standard deviations of the SLR projection uncertainties over each calibration year
colors = Dict(
    1 => "#1f77b4",  # muted blue
    2 => "#ff7f0e",  # orange
    3 => "#2ca02c",  # green
    4 => "#d62728",  # red
    5 => "#9467bd",  # purple
    6 => "#8c564b"   # brown
)

fig, ax = PyPlot.subplots(nrows=3, ncols=1, figsize=(15, 11), dpi=300)

ax[1].plot(collect(df_std_of_widths_slr[1:5,1]), collect(df_std_of_widths_slr[1:5,2]), color=colors[1],lw=3 )
ax[2].plot(collect(df_std_of_widths_slr[1:12,1]), collect(df_std_of_widths_slr[1:12,3]), color=colors[2],lw=3  )
ax[3].plot(collect(df_std_of_widths_slr[:,1]), collect(df_std_of_widths_slr[:,4]), color=colors[3],lw=3  )
ax[1].set_xlabel("Projection year 2100")
ax[2].set_xlabel("Projection year 2200")
ax[3].set_xlabel("Projection year 2300")
ax[1].set_xlim(2030,2090)
ax[2].set_xlim(2030,2195)
ax[3].set_xlim(2030,2300)
# Out:
# Figure(PyObject <Figure size 4500x3300 with 3 Axes>)
# (2030.0, 2300.0)
